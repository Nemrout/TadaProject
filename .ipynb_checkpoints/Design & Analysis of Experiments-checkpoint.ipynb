# %%
import pandas as pd

hot_drinks = [
    "Latte", "Black Coffee", "Green Tea", "Cappuccino", "Herbal Tea",
    "Espresso", "Hot Chocolate", "Americano", "Chai Latte", "Macchiato",
    "Flat White", "Mocha", "Oolong Tea", "Matcha Latte", "White Coffee",
    "Earl Grey Tea", "Pumpkin Spice Latte", "Turkish Coffee", "Peppermint Tea",
    "Decaf Coffee", "Soy Latte", "Ginger Tea", "Rooibos Tea", "Cortado",
    "Bulletproof Coffee", "Dandelion Coffee", "Hot Apple Cider", "Barley Tea",
    "Raspberry Hot Chocolate", "Hot Lemonade"
]

# %%
music_genres = [
    "Pop", "Rock", "Jazz", "Classical", "Hip-Hop",
    "Electronic", "Country", "Blues", "Indie", "Metal",
    "R&B", "Reggae", "Folk", "Gospel", "Latin",
    "Soul", "Opera", "K-Pop", "Punk", "EDM",
    "Ska", "Heavy Metal", "Grunge", "Disco", "Trance",
    "Techno", "Ambient", "Bluegrass", "Funk", "World Music"
]

# %%
frequency = [
    7, 3, 14, 5, 2, 10, 1, 6, 4, 9,
    8, 12, 7, 5, 3, 11, 4, 6, 2, 8,
    7, 10, 9, 5, 3, 12, 4, 11, 2, 6
]

# %%
movie_genres = [
    "Comedy", "Documentary", "Drama", "Action", "Romance",
    "Musical", "Fantasy", "Thriller", "Adventure", "Sci-Fi",
    "Horror", "Mystery", "Crime", "Animation", "War",
    "Western", "Historical", "Biographical", "Sports", "Family",
    "Superhero", "Noir", "Satire", "Teen", "Epic",
    "Dystopian", "Martial Arts", "Silent", "Experimental", "Cult"
]

# %%
professions = [
    "Teacher", "Android Developer", "Nurse", "Graphic Designer", "Writer",
    "Salesperson", "PE Instructor", "Lawyer", "Student", "IT Professional",
    "Project Manager", "Doctor", "Musician", "Marketing Specialist", "SMM Specialist",
    "Filmmaker", "Journalist", "Accountant", "Office Administrator", "Athlete",
    "Social Worker", "Developer", "Librarian", "Designer", "Developer",
    "Medical Student", "Electrician", "iOS Developer", "Carpenter", "Bartender"
]

# %%
df = pd.DataFrame({
    'Hot Drink': hot_drinks,
    'Music Genre': music_genres,
    'Movie Genre': movie_genres,
    'Frequency per Week': frequency,
    'Profession': professions
})

# %%
df
# Out:
#                   Hot Drink  Music Genre   Movie Genre  Frequency per Week  \
# 0                     Latte          Pop        Comedy                   7
# 1              Black Coffee         Rock   Documentary                   3
# 2                 Green Tea         Jazz         Drama                  14
# 3                Cappuccino    Classical        Action                   5
# 4                Herbal Tea      Hip-Hop       Romance                   2
# 5                  Espresso   Electronic       Musical                  10
# 6             Hot Chocolate      Country       Fantasy                   1
# 7                 Americano        Blues      Thriller                   6
# 8                Chai Latte        Indie     Adventure                   4
# 9                 Macchiato        Metal        Sci-Fi                   9
# 10               Flat White          R&B        Horror                   8
# ...
